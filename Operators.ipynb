# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerthanaaSivakumar/Keerthi/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("Enter mark1:\n"))
b=int(input("Enter mark2:\n"))
c=a+b
print("Total Mark:",c)

# %%
a=int(input("Enter the total amount:"))
b=int(input("Enter the withdraw amount:"))
c=a-b
print("The balance amount is:",c)

# %%
a=int(input("Enter the price of the product"))
b=int(input("Total no. of product"))
c=a*b
print("The total cost is",c)

# %%
a=int(input("Enter the total no. of chocolates"))
b=int(input("No. of children"))
c=int(a/b)
print("Each child gets",c,"chocolates")

# %%
a=int(input("Enter the total no. of chocolates"))
b=int(input("No. of children"))
c=int(a%b)
print("The no. of remaining chocolates after distribution",c)

# %%
a=int(input("Salary amount:"))
b=int(input("Bonus amount:"))
c=a+b
print("The total amount:",c)

# %%
a=int(input("Enter the theory mark:"))
b=int(input("Enter the lab mark:"))
if((a>39) and (b>39)):
  print("True")
else:
  print("False")

# %%
a=int(input("Enter the age of person1:"))
b=int(input("Enter the age of person2:"))
if(a>b):
  print("True")
else:
  print("False")

# %%
a=int(input("Enter the number:"))
b=a**2
print(b)

# %%
a=int(input("Num1:"))
b=int(input("Num2:"))
c=int(a&b)
print(c)
